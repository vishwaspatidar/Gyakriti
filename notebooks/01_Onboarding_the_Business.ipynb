# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
def load_dataset(file_name: str) -> pd.DataFrame:
    raw_data_dir = Path("/Users/vishwashpatidar/Project Gyakriti/Gyakriti/data/raw")
    return pd.read_csv(raw_data_dir / file_name)

# %%
DATA_PATH = Path("/Users/vishwashpatidar/Project Gyakriti/Gyakriti/data/raw")

customers = load_dataset("olist_customers_dataset.csv")
orders = load_dataset("olist_orders_dataset.csv")
items = load_dataset( "olist_order_items_dataset.csv")
payments = load_dataset( "olist_order_payments_dataset.csv")
review = load_dataset( "olist_order_reviews_dataset.csv")
geolocation = load_dataset( "olist_geolocation_dataset.csv")
products = load_dataset( "olist_products_dataset.csv")
seller = load_dataset( "olist_sellers_dataset.csv")
prod_cat = load_dataset ("product_category_name_translation.csv")

# %%
datasets = {
    "customers": customers,
    "orders": orders,
    "order_items": items,
    "payments": payments,
    "reviews": review,
    "products": products,
    "sellers": seller,
    "geolocation": geolocation,
    "prod_cat": prod_cat,
}

# %%
sumry = pd.DataFrame({
    "rows": [df.shape[0] for df in datasets.values()],
    "columns": [df.shape[1] for df in datasets.values()]
},
index = datasets.keys())

sumry
# Out:
#                 rows  columns
# customers      99441        5
# orders         99441        8
# order_items   112650        7
# payments      103886        5
# reviews        99224        7
# products       32951        9
# sellers         3095        4
# geolocation  1000163        5
# prod_cat          71        2

# %%
for name, df in datasets.items():
    print("=" * 60)
    print(name.upper())
    print(df.dtypes)
# Out:
# ...
# CUSTOMERS
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object
# ...
# ORDERS
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object
# ...
# ORDER_ITEMS
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object
# ...
# PAYMENTS
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# ...
